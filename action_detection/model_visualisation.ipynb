# %%
# !pip install pydot graphviz

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense
from tensorflow.keras.utils import plot_model
from IPython.display import display
import PIL.Image

# Define model parameters
input_shape = (15, 1662)  # Example input shape (adjust as needed)
actions_count = 5  # Number of output classes

# Define the model
model = Sequential([
    LSTM(32, return_sequences=True, recurrent_dropout=0.15, dropout=0.15, activation='relu', 
        input_shape=input_shape),
    BatchNormalization(),
    LSTM(16, return_sequences=False, recurrent_dropout=0.15, dropout=0.15, activation='relu'),
    BatchNormalization(),
    Dense(32, activation='relu'),  
    Dense(16, activation='relu'), 
    Dense(actions_count, activation='softmax')
])

# Save the model plot
plot_path = "/Users/pe3nu7/Downloads/model.png"
plot_model(model, to_file=plot_path, show_shapes=True, show_layer_names=True)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
